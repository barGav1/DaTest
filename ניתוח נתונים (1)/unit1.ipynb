# %% [markdown]
# # Identify:
#
# Please fill-in your ID in the following cell, **only id numbers, no names!**
#
#
# <div style="direction:rtl">
# מלאו בתא הבא את מספר הת.ז שלכם. רק מספר ת.ז., ללא שמות!!
# </div>

# %%
id1 = "316390053"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error as mse

# %%
df = pd.DataFrame([id1])

# %%
df.to_clipboard(index=False,header=False)

# %% [markdown]
# ---

# %% [markdown]
# ----

# %%
url = 'https://raw.githubusercontent.com/nlihin/data-analytics/main/datasets/hotel_bookings.csv'
data = pd.read_csv(url)
data.head()
# Out:
#           hotel  is_canceled  lead_time  arrival_date_year arrival_date_month  \
# 0  Resort Hotel            0        342               2015               July
# 1  Resort Hotel            0        737               2015               July
# 2  Resort Hotel            0          7               2015               July
# 3  Resort Hotel            0         13               2015               July
# 4  Resort Hotel            0         14               2015               July
#
#    arrival_date_week_number  arrival_date_day_of_month  \
# 0                        27                          1
# 1                        27                          1
# 2                        27                          1
# 3                        27                          1
# 4                        27                          1
#
#    stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# 0                        0                     0       2  ...    No Deposit
# ...

# %%
data.dtypes
# Out:
# hotel                              object
# is_canceled                         int64
# lead_time                           int64
# arrival_date_year                   int64
# arrival_date_month                 object
# arrival_date_week_number            int64
# arrival_date_day_of_month           int64
# stays_in_weekend_nights             int64
# stays_in_week_nights                int64
# adults                              int64
# children                          float64
# babies                              int64
# meal                               object
# country                            object
# market_segment                     object
# distribution_channel               object
# is_repeated_guest                   int64
# previous_cancellations              int64
# previous_bookings_not_canceled      int64
# reserved_room_type                 object
# assigned_room_type                 object
# booking_changes                     int64
# ...

# %% [markdown]
# # Q1

# %%
data.boxplot('stays_in_weekend_nights')

# %% [markdown]
#  # Q2

# %%
df_M8=data[data.loc[:,'arrival_date_month'].str.contains('August')]
df_M8_B1=df_M8[data8.babies > 0]
df_M8_B1.head(5)
# Out:
#             hotel  is_canceled  lead_time  arrival_date_year  \
# 889  Resort Hotel            1        131               2015
# 898  Resort Hotel            0         13               2015
# 919  Resort Hotel            0         84               2015
# 951  Resort Hotel            0        116               2015
# 975  Resort Hotel            0        126               2015
#
#     arrival_date_month  arrival_date_week_number  arrival_date_day_of_month  \
# 889             August                        32                          3
# 898             August                        32                          4
# 919             August                        32                          5
# 951             August                        32                          7
# 975             August                        32                          8
#
#      stays_in_weekend_nights  stays_in_week_nights  adults  ...  deposit_type  \
# ...

# %%
len(df_M8_B1.index)
# Out:
# 195

# %% [markdown]
# # Q3

# %%
sns.countplot(y='hotel', hue='reservation_status', data=data)

# %% [markdown]
# # Q4

# %%
data.groupby(['arrival_date_month', 'hotel'])['adults'].sum().unstack()
# Out:
# hotel               City Hotel  Resort Hotel
# arrival_date_month
# April                    14290          6516
# August                   17841          9954
# December                  7609          4773
# February                  8846          5604
# January                   6378          3646
# July                     15975          9189
# June                     14519          5834
# March                    11858          5817
# May                      14958          6581
# November                  7330          4158
# October                  13665          6614
# September                13569          6112

# %% [markdown]
# # Q5

# %%
data[features].plot.density(subplots=True, sharex=False, sharey=False, layout=(5, 2), figsize=(12,14))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x0000011A387E89E8>,
# ...
#       dtype=object)

# %%
features = ['stays_in_week_nights', 'stays_in_weekend_nights','customer_type', 'previous_cancellations', 'booking_changes',
            'babies', 'is_repeated_guest','previous_bookings_not_canceled','days_in_waiting_list', 'lead_time', 'is_canceled' ]
corrs = data[features].corr(method = 'spearman')
plt.figure(figsize=(15,10))  #figure size
sns.heatmap(corrs, cmap='coolwarm', center=0, annot = True);

# %%
sns.scatterplot(data=data, x="lead_time",y='stays_in_week_nights')

# %% [markdown]
# # Q6

# %%
features = ['stays_in_week_nights', 'stays_in_weekend_nights', 'previous_cancellations', 'booking_changes',
            'babies', 'is_repeated_guest','previous_bookings_not_canceled','days_in_waiting_list', 'lead_time']
X = data[features]
y = data['is_canceled']
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.3,random_state=1)  
#1model = DecisionTreeRegressor(random_state=1)
model = sk.tree.DecisionTreeClassifier(criterion="gini", max_depth=1, random_state=0)
model.fit(X_train,y_train)
pred=model.predict(X_test)
#1mse(pred,y_test,squared=False)
acc = sk.metrics.accuracy_score(pred, y_test)
acc
# Out:
# 0.6764944020995617

# %% [markdown]
# ניתן להגיד באופן מלא שהדיוק הוא יותר מדויק מדיוק מקרי כי הוא גדול מחצי
# אם ישנם שתי האפשרויות האופציה לחיזוי מקרית היא כמו בהטלת מטבע זאת אומרת חמישים אחוז
# בגלל ש acc>0.5 (acc=0.6764944020995617)
# אז ניתן להגיד שהמודל יותר טוב מדיוק מקרי

# %% [markdown]
# ---
# # GOOD LUCK !!!!
# ---

# %%
# do not type below this line
