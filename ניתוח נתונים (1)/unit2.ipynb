# %% [markdown]
# # Unit 2
# ---
#
#
#
#
# 1. [Introducing Pandas](#section1)
# 2. [Reading files](#section2)
# 3. [Selecting data](#section3)
# 4. [Conditional selection](#section4)

# %% [markdown]
# <a id='section1'></a>

# %% [markdown]
# ## 1. Introducing Pandas
# ---
#
# <div>
# <img src="images/pandas.JPG" width="400"/>
# </div>
#
#
#
# [Panda's documentation](https://pandas.pydata.org/pandas-docs/stable/)

# %% [markdown]
# To begin we need to import pandas
# When you see pd, know it is referring to pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Pandas is a popular Python library used for working in tabular data (similar to the data stored in a spreadsheet).
#
# There are two main data structure used by pandas
# - Series: like a vector or a list
# - Dataframe: equivalent to a table.
#
# Each column in a pandas Dataframe is a pandas Series data structure. We will mainly be looking at the Dataframe.
#
# We can easily create a Pandas Dataframe by reading a .csv file

# %% [markdown]
# <a id='section2'></a>

# %% [markdown]
# ## 2. Reading files
# ---
#
# <div>
# <img src="images/reading.PNG" width="400"/>
# </div>
#
#
# We will read the whole file at once using Pandas.
# Sometimes you might want to read the file line by line, and process each line. Thats possible of course. See for example [here.](https://www.geeksforgeeks.org/read-a-file-line-by-line-in-python/)
#
# We will read data on [COVID-19 vaccinations](https://github.com/owid/covid-19-data/tree/master/public/data/vaccinations)
#
# In order to do that, I retrieved the raw data's url
#
# <div>
# <img src="images/raw.png" width="800"/>
# </div>

# %%
url = 'https://raw.githubusercontent.com/owid/covid-19-data/master/public/data/vaccinations/vaccinations.csv'
vacc_df = pd.read_csv(url)

# %% [markdown]
# read_csv has about 30 different options. See the
# [documentation](https://pandas.pydata.org/pandasdocs/stable/reference/api/pandas.read_csv.html#pandas.read_csv)
#
# For example, sep='\t' is used for tab delimited files and 'usecol' reads only specific columns.

# %%
type(vacc_df)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# view the shape of the dataframe:

# %%
vacc_df
# Out:
#           location iso_code        date  total_vaccinations  \
# 0      Afghanistan      AFG  2021-02-22                 0.0
# 1      Afghanistan      AFG  2021-02-23                 NaN
# 2      Afghanistan      AFG  2021-02-24                 NaN
# 3      Afghanistan      AFG  2021-02-25                 NaN
# 4      Afghanistan      AFG  2021-02-26                 NaN
# ...            ...      ...         ...                 ...
# 23501     Zimbabwe      ZWE  2021-05-27            953389.0
# 23502     Zimbabwe      ZWE  2021-05-28            976796.0
# 23503     Zimbabwe      ZWE  2021-05-29           1002465.0
# 23504     Zimbabwe      ZWE  2021-05-30           1011973.0
# 23505     Zimbabwe      ZWE  2021-05-31           1020078.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 0                    0.0                      NaN                     NaN
# 1                    NaN                      NaN                     NaN
# 2                    NaN                      NaN                     NaN
# 3                    NaN                      NaN                     NaN
# 4                    NaN                      NaN                     NaN
# ...                  ...                      ...                     ...
# 23501           648121.0                 305268.0                 16349.0
# 23502           656630.0                 320166.0                 23407.0
# 23503           666786.0                 335679.0                 25669.0
# 23504           670755.0                 341218.0                  9508.0
# 23505           675678.0                 344400.0                  8105.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 0                     NaN                            0.00
# 1                  1367.0                             NaN
# 2                  1367.0                             NaN
# 3                  1367.0                             NaN
# 4                  1367.0                             NaN
# ...                   ...                             ...
# 23501             12285.0                            6.41
# 23502             12695.0                            6.57
# 23503             14056.0                            6.74
# 23504             14420.0                            6.81
# 23505             15022.0                            6.86
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 0                               0.00                                  NaN
# 1                                NaN                                  NaN
# 2                                NaN                                  NaN
# 3                                NaN                                  NaN
# 4                                NaN                                  NaN
# ...                              ...                                  ...
# 23501                           4.36                                 2.05
# 23502                           4.42                                 2.15
# 23503                           4.49                                 2.26
# 23504                           4.51                                 2.30
# 23505                           4.55                                 2.32
#
#        daily_vaccinations_per_million
# 0                                 NaN
# 1                                35.0
# 2                                35.0
# 3                                35.0
# 4                                35.0
# ...                               ...
# 23501                           827.0
# 23502                           854.0
# 23503                           946.0
# 23504                           970.0
# 23505                          1011.0
#
# [23506 rows x 12 columns]

# %% [markdown]
# view basic information:

# %%
vacc_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23506 entries, 0 to 23505
# Data columns (total 12 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   location                             23506 non-null  object
#  1   iso_code                             23506 non-null  object
#  2   date                                 23506 non-null  object
#  3   total_vaccinations                   14103 non-null  float64
#  4   people_vaccinated                    13307 non-null  float64
#  5   people_fully_vaccinated              10553 non-null  float64
#  6   daily_vaccinations_raw               11984 non-null  float64
#  7   daily_vaccinations                   23278 non-null  float64
#  8   total_vaccinations_per_hundred       14103 non-null  float64
#  9   people_vaccinated_per_hundred        13307 non-null  float64
#  10  people_fully_vaccinated_per_hundred  10553 non-null  float64
#  11  daily_vaccinations_per_million       23278 non-null  float64
# dtypes: float64(9), object(3)
# memory usage: 2.2+ MB

# %%
vacc_df.columns
# Out:
# Index(['location', 'iso_code', 'date', 'total_vaccinations',
#        'people_vaccinated', 'people_fully_vaccinated',
#        'daily_vaccinations_raw', 'daily_vaccinations',
#        'total_vaccinations_per_hundred', 'people_vaccinated_per_hundred',
#        'people_fully_vaccinated_per_hundred',
#        'daily_vaccinations_per_million'],
#       dtype='object')

# %% [markdown]
# View the first few rows:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %% [markdown]
# What do you think that the 'tail' command does? Try it out!
#
# What happens if we just type vacc_df, without a head or a tail?

# %%
vacc_df.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 23501  Zimbabwe      ZWE  2021-05-27            953389.0           648121.0
# 23502  Zimbabwe      ZWE  2021-05-28            976796.0           656630.0
# 23503  Zimbabwe      ZWE  2021-05-29           1002465.0           666786.0
# 23504  Zimbabwe      ZWE  2021-05-30           1011973.0           670755.0
# 23505  Zimbabwe      ZWE  2021-05-31           1020078.0           675678.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23501                 305268.0                 16349.0             12285.0
# 23502                 320166.0                 23407.0             12695.0
# 23503                 335679.0                 25669.0             14056.0
# 23504                 341218.0                  9508.0             14420.0
# 23505                 344400.0                  8105.0             15022.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 23501                            6.41                           4.36
# 23502                            6.57                           4.42
# 23503                            6.74                           4.49
# 23504                            6.81                           4.51
# 23505                            6.86                           4.55
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 23501                                 2.05                           827.0
# 23502                                 2.15                           854.0
# 23503                                 2.26                           946.0
# 23504                                 2.30                           970.0
# 23505                                 2.32                          1011.0

# %%
vacc_df.describe()
# Out:
#        total_vaccinations  people_vaccinated  people_fully_vaccinated  \
# count        1.410300e+04       1.330700e+04             1.055300e+04
# mean         2.656047e+07       1.489738e+07             8.060504e+06
# std          1.131013e+08       5.721222e+07             3.094186e+07
# min          0.000000e+00       0.000000e+00             1.000000e+00
# 25%          1.039355e+05       8.109850e+04             3.688500e+04
# 50%          8.161750e+05       6.021500e+05             3.119450e+05
# 75%          4.944926e+06       3.511914e+06             1.911143e+06
# max          1.937501e+09       8.409562e+08             4.303617e+08
#
#        daily_vaccinations_raw  daily_vaccinations  \
# count            1.198400e+04        2.327800e+04
# mean             6.504701e+05        3.294654e+05
# std              2.510323e+06        1.694184e+06
# min              0.000000e+00        0.000000e+00
# 25%              4.691500e+03        9.430000e+02
# 50%              2.562200e+04        7.712000e+03
# 75%              1.519355e+05        4.541900e+04
# max              4.032549e+07        3.322524e+07
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# count                    14103.000000                   13307.000000
# mean                        19.011819                      13.108453
# std                         26.402102                      16.787676
# min                          0.000000                       0.000000
# 25%                          1.610000                       1.370000
# 50%                          8.070000                       5.890000
# 75%                         25.635000                      18.600000
# max                        230.090000                     116.000000
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# count                         10553.000000                    23278.000000
# mean                              7.150422                     3111.603016
# std                              11.275678                     7895.901272
# min                               0.000000                        0.000000
# 25%                               0.600000                      337.000000
# 50%                               2.800000                     1567.000000
# 75%                               8.770000                     4309.000000
# max                             114.090000                  1000000.000000

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-1af01e636ada> in <module>
# ----> 1 help(describe())
#
# NameError: name 'describe' is not defined

# %% [markdown]
# A summary of the functions so far:
#
# * `pd.read_csv` - Read data from a CSV file into a Pandas `DataFrame` object
# * `.info()` - View basic infomation about rows, columns & data types
# * `.describe()` - View statistical information about numeric columns
# * `.columns` - Get the list of column names
# * `.shape` - Get the number of rows & columns as a tuple
# * `.head`, `.tail`

# %% [markdown]
# <a id='section3'></a>

# %% [markdown]
# ---
# ## 3. Selecting data
#
# ![](https://i.imgur.com/zfxLzEv.png)

# %%
# Pandas format is NOT similar to this
covid_data_list = [
    {'date': '2020-08-30', 'new_cases': 1444, 'new_deaths': 1, 'new_tests': 53541},
    {'date': '2020-08-31', 'new_cases': 1365, 'new_deaths': 4, 'new_tests': 42583},
    {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
    {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8 },
    {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6},
]
covid_data_list
# Out:
# [{'date': '2020-08-30',
#   'new_cases': 1444,
#   'new_deaths': 1,
#   'new_tests': 53541},
#  {'date': '2020-08-31',
#   'new_cases': 1365,
#   'new_deaths': 4,
#   'new_tests': 42583},
#  {'date': '2020-09-01', 'new_cases': 996, 'new_deaths': 6, 'new_tests': 54395},
#  {'date': '2020-09-02', 'new_cases': 975, 'new_deaths': 8},
#  {'date': '2020-09-03', 'new_cases': 1326, 'new_deaths': 6}]

# %%
# Pandas format is simliar to this
covid_data_dict = {
    'date':       ['2020-08-30', '2020-08-31', '2020-09-01', '2020-09-02', '2020-09-03'],
    'new_cases':  [1444, 1365, 996, 975, 1326],
    'new_deaths': [1, 4, 6, 8, 6],
    'new_tests': [53541, 42583, 54395, None, None]
}

# %% [markdown]
# #### The index of a dataframe doesn't have to be numeric

# %%
df = pd.DataFrame({'age':[30, 2, 12, 4, 32, 33, 69],
                   'color':['blue', 'green', 'red', 'white', 'gray', 'black', 'red'],
                   'food':['Steak', 'Lamb', 'Mango', 'Apple', 'Cheese', 'Melon', 'Beans'],
                   'height':[165, 70, 120, 80, 180, 172, 150],
                   'score':[4.6, 8.3, 9.0, 3.3, 1.8, 9.5, 2.2],
                   'state':['NY', 'TX', 'FL', 'AL', 'AK', 'TX', 'TX']
                   },
                  index=['Jane', 'Nick', 'Aaron', 'Penelope', 'Dean', 'Christina', 'Cornelia'])
df
# Out:
#            age  color    food  height  score state
# Jane        30   blue   Steak     165    4.6    NY
# Nick         2  green    Lamb      70    8.3    TX
# Aaron       12    red   Mango     120    9.0    FL
# Penelope     4  white   Apple      80    3.3    AL
# Dean        32   gray  Cheese     180    1.8    AK
# Christina   33  black   Melon     172    9.5    TX
# Cornelia    69    red   Beans     150    2.2    TX

# %% [markdown]
# In our case it just happens to be numeric:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.location
#is the same as this:
vacc_df['location']
# Out:
# 0        Afghanistan
# 1        Afghanistan
# 2        Afghanistan
# 3        Afghanistan
# 4        Afghanistan
#             ...
# 23501       Zimbabwe
# 23502       Zimbabwe
# 23503       Zimbabwe
# 23504       Zimbabwe
# 23505       Zimbabwe
# Name: location, Length: 23506, dtype: object

# %% [markdown]
# note: using the `.` notation is possible only for columns whose names do not contain spaces or special characters

# %% [markdown]
# what data type is vacc_df.location? (list? series? dataframe?)

# %%
type(vacc_df.location)
# Out:
# pandas.core.series.Series

# %%
#retrieve a specific cell
vacc_df.location[2131]
# Out:
# 'Barbados'

# %%
#retrieve two columns
vacc_df[['location','date']]
# Out:
#           location        date
# 0      Afghanistan  2021-02-22
# 1      Afghanistan  2021-02-23
# 2      Afghanistan  2021-02-24
# 3      Afghanistan  2021-02-25
# 4      Afghanistan  2021-02-26
# ...            ...         ...
# 23501     Zimbabwe  2021-05-27
# 23502     Zimbabwe  2021-05-28
# 23503     Zimbabwe  2021-05-29
# 23504     Zimbabwe  2021-05-30
# 23505     Zimbabwe  2021-05-31
#
# [23506 rows x 2 columns]

# %% [markdown]
# #### Seletcting subsets of rows and columns
#
# One way to do that is iloc.
#
# `.iloc` - selects subsets of rows and columns by integer location only

# %%
#Rows:
#vacc_df.iloc[0]  #first row
vacc_df.iloc[-1234] #last row
# Out:
# location                               United Kingdom
# iso_code                                          GBR
# date                                       2021-05-13
# total_vaccinations                         5.5435e+07
# people_vaccinated                          3.6116e+07
# people_fully_vaccinated                    1.9319e+07
# daily_vaccinations_raw                         637325
# daily_vaccinations                             514372
# total_vaccinations_per_hundred                  81.66
# people_vaccinated_per_hundred                    53.2
# people_fully_vaccinated_per_hundred             28.46
# daily_vaccinations_per_million                   7577
# Name: 22272, dtype: object

# %% [markdown]
# The : operator
#
#  - when used alone it means "everything"
#
# - also used to indicate a ***slice*** of values

# %%
vacc_df.iloc[1:2] # second and third row
vacc_df.iloc[[-1,2,22]] #a few specific rows

# Columns:
vacc_df.iloc[:,0] # first column of data frame  
vacc_df.iloc[:,1] # second column of data frame  
vacc_df.iloc[:,-1] # last column of data frame

#Rows and columns
vacc_df.iloc[0:5,1] # first five rows of dataframe
#vacc_df.iloc[1:3, 1:2] # first two columns of data frame with all rows
#vacc_df.iloc[[0,3,6,24], [0,5,6]] # 1st, 4th, 7th, 25th row + 1st 6th 7th columns.
vacc_df.iloc[700:770,8:9]
vacc_df.iloc[:,9]
# Out:
# 0        0.00
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN
#          ...
# 23501    4.36
# 23502    4.42
# 23503    4.49
# 23504    4.51
# 23505    4.55
# Name: people_vaccinated_per_hundred, Length: 23506, dtype: float64

# %%
vacc_df.iloc[0:19]
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 0   Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1   Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2   Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3   Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4   Afghanistan      AFG  2021-02-26                 NaN                NaN
# 5   Afghanistan      AFG  2021-02-27                 NaN                NaN
# 6   Afghanistan      AFG  2021-02-28              8200.0             8200.0
# 7   Afghanistan      AFG  2021-03-01                 NaN                NaN
# 8   Afghanistan      AFG  2021-03-02                 NaN                NaN
# 9   Afghanistan      AFG  2021-03-03                 NaN                NaN
# 10  Afghanistan      AFG  2021-03-04                 NaN                NaN
# 11  Afghanistan      AFG  2021-03-05                 NaN                NaN
# 12  Afghanistan      AFG  2021-03-06                 NaN                NaN
# 13  Afghanistan      AFG  2021-03-07                 NaN                NaN
# 14  Afghanistan      AFG  2021-03-08                 NaN                NaN
# 15  Afghanistan      AFG  2021-03-09                 NaN                NaN
# 16  Afghanistan      AFG  2021-03-10                 NaN                NaN
# 17  Afghanistan      AFG  2021-03-11                 NaN                NaN
# 18  Afghanistan      AFG  2021-03-12                 NaN                NaN
#
#     people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                       NaN                     NaN                 NaN
# 1                       NaN                     NaN              1367.0
# 2                       NaN                     NaN              1367.0
# 3                       NaN                     NaN              1367.0
# 4                       NaN                     NaN              1367.0
# 5                       NaN                     NaN              1367.0
# 6                       NaN                     NaN              1367.0
# 7                       NaN                     NaN              1580.0
# 8                       NaN                     NaN              1794.0
# 9                       NaN                     NaN              2008.0
# 10                      NaN                     NaN              2221.0
# 11                      NaN                     NaN              2435.0
# 12                      NaN                     NaN              2649.0
# 13                      NaN                     NaN              2862.0
# 14                      NaN                     NaN              2862.0
# 15                      NaN                     NaN              2862.0
# 16                      NaN                     NaN              2862.0
# 17                      NaN                     NaN              2862.0
# 18                      NaN                     NaN              2862.0
#
#     total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.00                           0.00
# 1                              NaN                            NaN
# 2                              NaN                            NaN
# 3                              NaN                            NaN
# 4                              NaN                            NaN
# 5                              NaN                            NaN
# 6                             0.02                           0.02
# 7                              NaN                            NaN
# 8                              NaN                            NaN
# 9                              NaN                            NaN
# 10                             NaN                            NaN
# 11                             NaN                            NaN
# 12                             NaN                            NaN
# 13                             NaN                            NaN
# 14                             NaN                            NaN
# 15                             NaN                            NaN
# 16                             NaN                            NaN
# 17                             NaN                            NaN
# 18                             NaN                            NaN
#
#     people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                   NaN                             NaN
# 1                                   NaN                            35.0
# 2                                   NaN                            35.0
# 3                                   NaN                            35.0
# 4                                   NaN                            35.0
# 5                                   NaN                            35.0
# 6                                   NaN                            35.0
# 7                                   NaN                            41.0
# 8                                   NaN                            46.0
# 9                                   NaN                            52.0
# 10                                  NaN                            57.0
# 11                                  NaN                            63.0
# 12                                  NaN                            68.0
# 13                                  NaN                            74.0
# 14                                  NaN                            74.0
# 15                                  NaN                            74.0
# 16                                  NaN                            74.0
# 17                                  NaN                            74.0
# 18                                  NaN                            74.0

# %% [markdown]
# What if I want to select the 'daily_vaccinations' column, but I don't remember which column it is?

# %% [markdown]
# Use `.loc`
#
# `.loc` - selects subsets of rows and columns by label only. Allowed inputs are:
#
# - A single label, e.g. 5 or 'a', (note that 5 is interpreted as a label of the index, and never as an integer position along the index).
#
# - A list or array of labels, e.g. ['a', 'b', 'c'].
#
# - A slice object with labels, e.g. 'a':'f'.

# %%
vacc_df.loc[:,'daily_vaccinations']
# Out:
# 0            NaN
# 1         1367.0
# 2         1367.0
# 3         1367.0
# 4         1367.0
#           ...
# 23501    12285.0
# 23502    12695.0
# 23503    14056.0
# 23504    14420.0
# 23505    15022.0
# Name: daily_vaccinations, Length: 23506, dtype: float64

# %% [markdown]
# I'm missing the location. Let's add it.

# %%
vacc_df.loc[0:3,['location','daily_vaccinations']]

#vacc_df.loc[0:4:,['location', 'total_vaccinations']]  this is to select specific rows
# Out:
#       location  daily_vaccinations
# 0  Afghanistan                 NaN
# 1  Afghanistan              1367.0
# 2  Afghanistan              1367.0
# 3  Afghanistan              1367.0

# %% [markdown]
# Semantics are similar to iloc. But note:
#
# - `iloc` excludes the last element.  `df.iloc[0:1000]` will return entries 0...999
# - `loc`, includes the last element.  `df.loc[0:1000]` will return entries 0...1000
#
# you try it! What is the difference between:
#
# > vacc_df.iloc[0:5]
#
# > vacc_df.loc[0:5]

# %%
 vacc_df.iloc[0:5,1:11]
# Out:
#   iso_code        date  total_vaccinations  people_vaccinated  \
# 0      AFG  2021-02-22                 0.0                0.0
# 1      AFG  2021-02-23                 NaN                NaN
# 2      AFG  2021-02-24                 NaN                NaN
# 3      AFG  2021-02-25                 NaN                NaN
# 4      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN

# %%
vacc_df.loc[0:5,1:11]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-73-b360ceb0594c> in <module>
# ----> 1 vacc_df.loc[0:5,1:11]
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1053             return self._multi_take(tup)
#    1054
# -> 1055         return self._getitem_tuple_same_dim(tup)
#    1056
#    1057     def _get_label(self, label, axis: int):
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple_same_dim(self, tup)
#     748                 continue
#     749
# --> 750             retval = getattr(retval, self.name)._getitem_axis(key, axis=i)
#     751             # We should never have retval.ndim < self.ndim, as that should
#     752             #  be handled by the _getitem_lowerdim call above.
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1086         if isinstance(key, slice):
#    1087             self._validate_key(key, axis)
# -> 1088             return self._get_slice_axis(key, axis=axis)
#    1089         elif com.is_bool_indexer(key):
#    1090             return self._getbool_axis(key, axis=axis)
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _get_slice_axis(self, slice_obj, axis)
#    1120
#    1121         labels = obj._get_axis(axis)
# -> 1122         indexer = labels.slice_indexer(
#    1123             slice_obj.start, slice_obj.stop, slice_obj.step, kind="loc"
#    1124         )
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_indexer(self, start, end, step, kind)
#    4964         slice(1, 3, None)
#    4965         """
# -> 4966         start_slice, end_slice = self.slice_locs(start, end, step=step, kind=kind)
#    4967
#    4968         # return a slice
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in slice_locs(self, start, end, step, kind)
#    5165         start_slice = None
#    5166         if start is not None:
# -> 5167             start_slice = self.get_slice_bound(start, "left", kind)
#    5168         if start_slice is None:
#    5169             start_slice = 0
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_slice_bound(self, label, side, kind)
#    5077         # For datetime indices label may be a string that has to be converted
#    5078         # to datetime boundary according to its resolution.
# -> 5079         label = self._maybe_cast_slice_bound(label, side, kind)
#    5080
#    5081         # we need to look up the label
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _maybe_cast_slice_bound(self, label, side, kind)
#    5029         # this is rejected (generally .loc gets you here)
#    5030         elif is_integer(label):
# -> 5031             self._invalid_indexer("slice", label)
#    5032
#    5033         return label
#
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3265         Consistent invalid indexer message.
#    3266         """
# -> 3267         raise TypeError(
#    3268             f"cannot do {form} indexing on {type(self).__name__} with these "
#    3269             f"indexers [{key}] of type {type(key).__name__}"
#
# TypeError: cannot do slice indexing on Index with these indexers [1] of type int

# %% [markdown]
# ---
# ---
#
# Now you:
#
# what do you do to select:
#
# a. first five rows?
#
# b. first two columns, all rows?
#
# c. 1st and 3rd row and 2nd and 4th column?
#
# ---
# ---

# %% [markdown]
# a. the first five rows are:

# %%
vacc_df.head()
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 0  Afghanistan      AFG  2021-02-22                 0.0                0.0
# 1  Afghanistan      AFG  2021-02-23                 NaN                NaN
# 2  Afghanistan      AFG  2021-02-24                 NaN                NaN
# 3  Afghanistan      AFG  2021-02-25                 NaN                NaN
# 4  Afghanistan      AFG  2021-02-26                 NaN                NaN
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN              1367.0
# 2                      NaN                     NaN              1367.0
# 3                      NaN                     NaN              1367.0
# 4                      NaN                     NaN              1367.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 0                             0.0                            0.0
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#    people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 0                                  NaN                             NaN
# 1                                  NaN                            35.0
# 2                                  NaN                            35.0
# 3                                  NaN                            35.0
# 4                                  NaN                            35.0

# %%
vacc_df.iloc [:,0:2]
# Out:
#           location iso_code
# 0      Afghanistan      AFG
# 1      Afghanistan      AFG
# 2      Afghanistan      AFG
# 3      Afghanistan      AFG
# 4      Afghanistan      AFG
# ...            ...      ...
# 23501     Zimbabwe      ZWE
# 23502     Zimbabwe      ZWE
# 23503     Zimbabwe      ZWE
# 23504     Zimbabwe      ZWE
# 23505     Zimbabwe      ZWE
#
# [23506 rows x 2 columns]

# %%
vacc_df.iloc[[1,3],[2,4]]
# Out:
#          date  people_vaccinated
# 1  2021-02-23                NaN
# 3  2021-02-25                NaN

# %% [markdown]
# ---
# A summary of the functions in this unit:
#
# * `.iloc` - selects rows and columns by integer location
# * `.loc` - selects rows and columns by label location

# %% [markdown]
# Note: indexing operators as the ones working on dictionaries, will also work in pandas. But for more advanced operations, better get used to loc and iloc.
#
# ---

# %% [markdown]
# <a id='section4'></a>

# %% [markdown]
# ## 4. Conditional selection

# %%
vacc_df.loc[:,'location'] == 'Israel'
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 23501    False
# 23502    False
# 23503    False
# 23504    False
# 23505    False
# Name: location, Length: 23506, dtype: bool

# %% [markdown]
# This creates a series of true/false
#
# We can insert this into data to select only that task:

# %%
vacc_df[vacc_df.loc[:,'location'] == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 10349   Israel      ISR  2020-12-19                60.0               60.0
# 10350   Israel      ISR  2020-12-20              7419.0             7419.0
# 10351   Israel      ISR  2020-12-21             32302.0            32302.0
# 10352   Israel      ISR  2020-12-22             76920.0            76920.0
# 10353   Israel      ISR  2020-12-23            139760.0           139760.0
# ...        ...      ...         ...                 ...                ...
# 10508   Israel      ISR  2021-05-27          10574763.0          5447371.0
# 10509   Israel      ISR  2021-05-28          10576599.0          5447984.0
# 10510   Israel      ISR  2021-05-29          10576836.0          5448078.0
# 10511   Israel      ISR  2021-05-30          10580056.0          5449465.0
# 10512   Israel      ISR  2021-05-31          10583468.0          5450969.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10349                      NaN                     NaN                 NaN
# 10350                      NaN                  7359.0              7359.0
# 10351                      NaN                 24883.0             16121.0
# 10352                      NaN                 44618.0             25620.0
# 10353                      NaN                 62840.0             34925.0
# ...                        ...                     ...                 ...
# 10508                5127392.0                  4522.0              3626.0
# 10509                5128615.0                  1836.0              3572.0
# 10510                5128758.0                   237.0              3540.0
# 10511                5130591.0                  3220.0              3242.0
# 10512                5132499.0                  3412.0              2962.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10349                            0.00                           0.00
# 10350                            0.09                           0.09
# 10351                            0.37                           0.37
# 10352                            0.89                           0.89
# 10353                            1.61                           1.61
# ...                               ...                            ...
# 10508                          122.17                          62.94
# 10509                          122.19                          62.94
# 10510                          122.20                          62.94
# 10511                          122.23                          62.96
# 10512                          122.27                          62.98
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 10349                                  NaN                             NaN
# 10350                                  NaN                           850.0
# 10351                                  NaN                          1863.0
# 10352                                  NaN                          2960.0
# 10353                                  NaN                          4035.0
# ...                                    ...                             ...
# 10508                                59.24                           419.0
# 10509                                59.25                           413.0
# 10510                                59.25                           409.0
# 10511                                59.28                           375.0
# 10512                                59.30                           342.0
#
# [164 rows x 12 columns]

# %% [markdown]
# Another way:

# %%
vacc_df.loc[vacc_df.location == 'Israel']
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 10349   Israel      ISR  2020-12-19                60.0               60.0
# 10350   Israel      ISR  2020-12-20              7419.0             7419.0
# 10351   Israel      ISR  2020-12-21             32302.0            32302.0
# 10352   Israel      ISR  2020-12-22             76920.0            76920.0
# 10353   Israel      ISR  2020-12-23            139760.0           139760.0
# ...        ...      ...         ...                 ...                ...
# 10508   Israel      ISR  2021-05-27          10574763.0          5447371.0
# 10509   Israel      ISR  2021-05-28          10576599.0          5447984.0
# 10510   Israel      ISR  2021-05-29          10576836.0          5448078.0
# 10511   Israel      ISR  2021-05-30          10580056.0          5449465.0
# 10512   Israel      ISR  2021-05-31          10583468.0          5450969.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10349                      NaN                     NaN                 NaN
# 10350                      NaN                  7359.0              7359.0
# 10351                      NaN                 24883.0             16121.0
# 10352                      NaN                 44618.0             25620.0
# 10353                      NaN                 62840.0             34925.0
# ...                        ...                     ...                 ...
# 10508                5127392.0                  4522.0              3626.0
# 10509                5128615.0                  1836.0              3572.0
# 10510                5128758.0                   237.0              3540.0
# 10511                5130591.0                  3220.0              3242.0
# 10512                5132499.0                  3412.0              2962.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10349                            0.00                           0.00
# 10350                            0.09                           0.09
# 10351                            0.37                           0.37
# 10352                            0.89                           0.89
# 10353                            1.61                           1.61
# ...                               ...                            ...
# 10508                          122.17                          62.94
# 10509                          122.19                          62.94
# 10510                          122.20                          62.94
# 10511                          122.23                          62.96
# 10512                          122.27                          62.98
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 10349                                  NaN                             NaN
# 10350                                  NaN                           850.0
# 10351                                  NaN                          1863.0
# 10352                                  NaN                          2960.0
# 10353                                  NaN                          4035.0
# ...                                    ...                             ...
# 10508                                59.24                           419.0
# 10509                                59.25                           413.0
# 10510                                59.25                           409.0
# 10511                                59.28                           375.0
# 10512                                59.30                           342.0
#
# [164 rows x 12 columns]

# %% [markdown]
# Select two countries:

# %%
two_countries = vacc_df.loc[(vacc_df.location == 'Israel') | (vacc_df.location == 'Denmark')]
two_countries
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 5278   Denmark      DNK  2020-12-17                 1.0                1.0
# 5279   Denmark      DNK  2020-12-18                 NaN                NaN
# 5280   Denmark      DNK  2020-12-19                 2.0                2.0
# 5281   Denmark      DNK  2020-12-20                 NaN                NaN
# 5282   Denmark      DNK  2020-12-21                 3.0                3.0
# ...        ...      ...         ...                 ...                ...
# 10508   Israel      ISR  2021-05-27          10574763.0          5447371.0
# 10509   Israel      ISR  2021-05-28          10576599.0          5447984.0
# 10510   Israel      ISR  2021-05-29          10576836.0          5448078.0
# 10511   Israel      ISR  2021-05-30          10580056.0          5449465.0
# 10512   Israel      ISR  2021-05-31          10583468.0          5450969.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 5278                       NaN                     NaN                 NaN
# 5279                       NaN                     NaN                 0.0
# 5280                       NaN                     NaN                 0.0
# 5281                       NaN                     NaN                 0.0
# 5282                       NaN                     NaN                 0.0
# ...                        ...                     ...                 ...
# 10508                5127392.0                  4522.0              3626.0
# 10509                5128615.0                  1836.0              3572.0
# 10510                5128758.0                   237.0              3540.0
# 10511                5130591.0                  3220.0              3242.0
# 10512                5132499.0                  3412.0              2962.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 5278                             0.00                           0.00
# 5279                              NaN                            NaN
# 5280                             0.00                           0.00
# 5281                              NaN                            NaN
# 5282                             0.00                           0.00
# ...                               ...                            ...
# 10508                          122.17                          62.94
# 10509                          122.19                          62.94
# 10510                          122.20                          62.94
# 10511                          122.23                          62.96
# 10512                          122.27                          62.98
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 5278                                   NaN                             NaN
# 5279                                   NaN                             0.0
# 5280                                   NaN                             0.0
# 5281                                   NaN                             0.0
# 5282                                   NaN                             0.0
# ...                                    ...                             ...
# 10508                                59.24                           419.0
# 10509                                59.25                           413.0
# 10510                                59.25                           409.0
# 10511                                59.28                           375.0
# 10512                                59.30                           342.0
#
# [329 rows x 12 columns]

# %% [markdown]
# only the indexs of the tasks:

# %%
two_countries.index.values
# Out:
# array([ 5278,  5279,  5280,  5281,  5282,  5283,  5284,  5285,  5286,
#         5287,  5288,  5289,  5290,  5291,  5292,  5293,  5294,  5295,
#         5296,  5297,  5298,  5299,  5300,  5301,  5302,  5303,  5304,
#         5305,  5306,  5307,  5308,  5309,  5310,  5311,  5312,  5313,
#         5314,  5315,  5316,  5317,  5318,  5319,  5320,  5321,  5322,
#         5323,  5324,  5325,  5326,  5327,  5328,  5329,  5330,  5331,
#         5332,  5333,  5334,  5335,  5336,  5337,  5338,  5339,  5340,
#         5341,  5342,  5343,  5344,  5345,  5346,  5347,  5348,  5349,
#         5350,  5351,  5352,  5353,  5354,  5355,  5356,  5357,  5358,
#         5359,  5360,  5361,  5362,  5363,  5364,  5365,  5366,  5367,
#         5368,  5369,  5370,  5371,  5372,  5373,  5374,  5375,  5376,
#         5377,  5378,  5379,  5380,  5381,  5382,  5383,  5384,  5385,
#         5386,  5387,  5388,  5389,  5390,  5391,  5392,  5393,  5394,
#         5395,  5396,  5397,  5398,  5399,  5400,  5401,  5402,  5403,
#         5404,  5405,  5406,  5407,  5408,  5409,  5410,  5411,  5412,
#         5413,  5414,  5415,  5416,  5417,  5418,  5419,  5420,  5421,
#         5422,  5423,  5424,  5425,  5426,  5427,  5428,  5429,  5430,
#         5431,  5432,  5433,  5434,  5435,  5436,  5437,  5438,  5439,
#         5440,  5441,  5442, 10349, 10350, 10351, 10352, 10353, 10354,
#        10355, 10356, 10357, 10358, 10359, 10360, 10361, 10362, 10363,
#        10364, 10365, 10366, 10367, 10368, 10369, 10370, 10371, 10372,
#        10373, 10374, 10375, 10376, 10377, 10378, 10379, 10380, 10381,
#        10382, 10383, 10384, 10385, 10386, 10387, 10388, 10389, 10390,
#        10391, 10392, 10393, 10394, 10395, 10396, 10397, 10398, 10399,
#        10400, 10401, 10402, 10403, 10404, 10405, 10406, 10407, 10408,
#        10409, 10410, 10411, 10412, 10413, 10414, 10415, 10416, 10417,
#        10418, 10419, 10420, 10421, 10422, 10423, 10424, 10425, 10426,
#        10427, 10428, 10429, 10430, 10431, 10432, 10433, 10434, 10435,
#        10436, 10437, 10438, 10439, 10440, 10441, 10442, 10443, 10444,
#        10445, 10446, 10447, 10448, 10449, 10450, 10451, 10452, 10453,
#        10454, 10455, 10456, 10457, 10458, 10459, 10460, 10461, 10462,
#        10463, 10464, 10465, 10466, 10467, 10468, 10469, 10470, 10471,
#        10472, 10473, 10474, 10475, 10476, 10477, 10478, 10479, 10480,
#        10481, 10482, 10483, 10484, 10485, 10486, 10487, 10488, 10489,
#        10490, 10491, 10492, 10493, 10494, 10495, 10496, 10497, 10498,
#        10499, 10500, 10501, 10502, 10503, 10504, 10505, 10506, 10507,
#        10508, 10509, 10510, 10511, 10512], dtype=int64)

# %% [markdown]
# the index in the first place:

# %%
two_countries.index.values[0]
# Out:
# 5278

# %% [markdown]
# how many rows for the two countries?

# %%
two_countries.count()
# Out:
# location                               329
# iso_code                               329
# date                                   329
# total_vaccinations                     326
# people_vaccinated                      326
# people_fully_vaccinated                295
# daily_vaccinations_raw                 321
# daily_vaccinations                     327
# total_vaccinations_per_hundred         326
# people_vaccinated_per_hundred          326
# people_fully_vaccinated_per_hundred    295
# daily_vaccinations_per_million         327
# dtype: int64

# %% [markdown]
# At the end of the file we have some world data.
#
# Use str.contains if you're not sure how this location is called

# %%
vacc_df[vacc_df['location'].str.contains('World')]
# Out:
#       location  iso_code        date  total_vaccinations  people_vaccinated  \
# 23154    World  OWID_WRL  2020-12-02        1.000000e+00                1.0
# 23155    World  OWID_WRL  2020-12-03        1.000000e+00                1.0
# 23156    World  OWID_WRL  2020-12-04        2.000000e+00                2.0
# 23157    World  OWID_WRL  2020-12-05        2.000000e+00                2.0
# 23158    World  OWID_WRL  2020-12-06        2.000000e+00                2.0
# ...        ...       ...         ...                 ...                ...
# 23330    World  OWID_WRL  2021-05-27        1.813771e+09        810431629.0
# 23331    World  OWID_WRL  2021-05-28        1.845718e+09        818819847.0
# 23332    World  OWID_WRL  2021-05-29        1.876595e+09        827707203.0
# 23333    World  OWID_WRL  2021-05-30        1.906443e+09        835289867.0
# 23334    World  OWID_WRL  2021-05-31        1.937501e+09        840956152.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23154                      NaN                     NaN                 NaN
# 23155                      NaN                     0.0                 0.0
# 23156                      NaN                     1.0                 0.0
# 23157                      NaN                     0.0                 0.0
# 23158                      NaN                     0.0                 0.0
# ...                        ...                     ...                 ...
# 23330              414771680.0              33957660.0          31080505.0
# 23331              419760225.0              31947359.0          31483414.0
# 23332              423563234.0              30876843.0          32007393.0
# 23333              427421843.0              29848009.0          32897914.0
# 23334              430361678.0              31057911.0          33225237.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 23154                            0.00                           0.00
# 23155                            0.00                           0.00
# 23156                            0.00                           0.00
# 23157                            0.00                           0.00
# 23158                            0.00                           0.00
# ...                               ...                            ...
# 23330                           23.27                          10.40
# 23331                           23.68                          10.50
# 23332                           24.07                          10.62
# 23333                           24.46                          10.72
# 23334                           24.86                          10.79
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 23154                                  NaN                             NaN
# 23155                                  NaN                             0.0
# 23156                                  NaN                             0.0
# 23157                                  NaN                             0.0
# 23158                                  NaN                             0.0
# ...                                    ...                             ...
# 23330                                 5.32                          3987.0
# 23331                                 5.39                          4039.0
# 23332                                 5.43                          4106.0
# 23333                                 5.48                          4220.0
# 23334                                 5.52                          4262.0
#
# [181 rows x 12 columns]

# %% [markdown]
# Remove the world data:

# %%
vacc_df_noWorld = vacc_df.loc[vacc_df.location != 'World']
vacc_df_noWorld.tail()
# Out:
#        location iso_code        date  total_vaccinations  people_vaccinated  \
# 23501  Zimbabwe      ZWE  2021-05-27            953389.0           648121.0
# 23502  Zimbabwe      ZWE  2021-05-28            976796.0           656630.0
# 23503  Zimbabwe      ZWE  2021-05-29           1002465.0           666786.0
# 23504  Zimbabwe      ZWE  2021-05-30           1011973.0           670755.0
# 23505  Zimbabwe      ZWE  2021-05-31           1020078.0           675678.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 23501                 305268.0                 16349.0             12285.0
# 23502                 320166.0                 23407.0             12695.0
# 23503                 335679.0                 25669.0             14056.0
# 23504                 341218.0                  9508.0             14420.0
# 23505                 344400.0                  8105.0             15022.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 23501                            6.41                           4.36
# 23502                            6.57                           4.42
# 23503                            6.74                           4.49
# 23504                            6.81                           4.51
# 23505                            6.86                           4.55
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 23501                                 2.05                           827.0
# 23502                                 2.15                           854.0
# 23503                                 2.26                           946.0
# 23504                                 2.30                           970.0
# 23505                                 2.32                          1011.0

# %% [markdown]
# Find the country with the maximum vaccinations:

# %%
max_vacc = vacc_df_noWorld.total_vaccinations.max()
max_vacc
# Out:
# 1062201277.0

# %%
vacc_df_noWorld.loc[vacc_df_noWorld.total_vaccinations == max_vacc]
# Out:
#      location  iso_code        date  total_vaccinations  people_vaccinated  \
# 1266     Asia  OWID_ASI  2021-05-31        1.062201e+09        276224506.0
#
#       people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 1266              104895621.0              26636410.0          24089671.0
#
#       total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 1266                           22.89                           5.95
#
#       people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 1266                                 2.26                          5192.0

# %% [markdown]
# What do you think this function does?

# %%
vacc_df_noWorld.total_vaccinations.mean()
# Out:
# 20317402.17662692

# %% [markdown]
# ----
# #### Your turn:

# %% [markdown]
# Select the number of daily vaccinations in Israel on date 2021-02-06 (hint: use &)

# %%
vacc_df.loc[(vacc_df.location == 'Israel') & (vacc_df.date == '2021-02-06')]
# Out:
#       location iso_code        date  total_vaccinations  people_vaccinated  \
# 10398   Israel      ISR  2021-02-06           5517761.0          3442374.0
#
#        people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 10398                2075387.0                 43668.0             99784.0
#
#        total_vaccinations_per_hundred  people_vaccinated_per_hundred  \
# 10398                           63.75                          39.77
#
#        people_fully_vaccinated_per_hundred  daily_vaccinations_per_million
# 10398                                23.98                         11528.0

# %% [markdown]
# Find all the countries with more than 3000000 vaccinations

# %%
vacc_df_noWorld.loc[(vacc_df.daily_vaccinations > 300000)]
# Out:
#                   location  iso_code        date  total_vaccinations  \
# 175                 Africa  OWID_AFR  2021-03-27          10302320.0
# 176                 Africa  OWID_AFR  2021-03-28          10561169.0
# 177                 Africa  OWID_AFR  2021-03-29          10774084.0
# 178                 Africa  OWID_AFR  2021-03-30          10970869.0
# 218                 Africa  OWID_AFR  2021-05-09          21198985.0
# ...                    ...       ...         ...                 ...
# 22615  Upper middle income  OWID_UMC  2021-05-27         822880783.0
# 22616  Upper middle income  OWID_UMC  2021-05-28         844859174.0
# 22617  Upper middle income  OWID_UMC  2021-05-29         865304962.0
# 22618  Upper middle income  OWID_UMC  2021-05-30         886276477.0
# 22619  Upper middle income  OWID_UMC  2021-05-31         909888247.0
#
#        people_vaccinated  people_fully_vaccinated  daily_vaccinations_raw  \
# 175            6886943.0                3606160.0                325837.0
# 176            7143129.0                3608823.0                258849.0
# 177            7229895.0                3743032.0                212915.0
# 178            7311247.0                3870507.0                196785.0
# 218           15987716.0                5518749.0                729471.0
# ...                  ...                      ...                     ...
# 22615        156476628.0               85995305.0              21093601.0
# 22616        158683995.0               87125564.0              21978391.0
# 22617        160384542.0               87689754.0              20445788.0
# 22618        162275624.0               88521156.0              20971515.0
# 22619        163188940.0               88918704.0              23611770.0
#
#        daily_vaccinations  total_vaccinations_per_hundred  \
# 175              301154.0                            0.77
# 176              335054.0                            0.79
# 177              348008.0                            0.80
# 178              355231.0                            0.82
# 218              351787.0                            1.58
# ...                   ...                             ...
# 22615          20642008.0                           31.00
# 22616          20979756.0                           31.82
# 22617          21568527.0                           32.59
# 22618          22392985.0                           33.38
# 22619          23060792.0                           34.27
#
#        people_vaccinated_per_hundred  people_fully_vaccinated_per_hundred  \
# 175                             0.51                                 0.27
# 176                             0.53                                 0.27
# 177                             0.54                                 0.28
# 178                             0.55                                 0.29
# 218                             1.19                                 0.41
# ...                              ...                                  ...
# 22615                           5.89                                 3.24
# 22616                           5.98                                 3.28
# 22617                           6.04                                 3.30
# 22618                           6.11                                 3.33
# 22619                           6.15                                 3.35
#
#        daily_vaccinations_per_million
# 175                             225.0
# 176                             250.0
# 177                             260.0
# 178                             265.0
# 218                             262.0
# ...                               ...
# 22615                          7775.0
# 22616                          7903.0
# 22617                          8124.0
# 22618                          8435.0
# 22619                          8686.0
#
# [2234 rows x 12 columns]

# %% [markdown]
# ---
# Summary of the functions in this unit:
#
# * `.index.values` - the row indexes of this part of the dataframes
# * `.str.contains` - selects rows and columns that contain a string
# * `.max` - maximum value
# * `.mean` - average value
# * `.count` - the number of rows that contain a value
